# %%
import pandas as pd
from google.cloud import storage

from pprint import pprint
import json

# %% [markdown]
# Make sure you set your [GOOGLE_APPLICATION_CREDENTIALS variable](https://cloud.google.com/docs/authentication/production#linux-or-macos) to the usage-metrics service account key.

# %%
BUCKET_NAME = "github-metrics"

# %%
def extract_clones(metric_json):
    return pd.DataFrame(metric_json["clones"])

def extract_views(metric_json):
    return pd.DataFrame(metric_json["views"])

def extract_popular_paths(metric_json):
    return pd.DataFrame(metric_json)

def extract_popular_referrers(metric_json):
    return pd.DataFrame(metric_json)

def extract_stargazers(metric_json):
    trns_metric_json = []
    for stargazer in metric_json:
        user = stargazer["user"]
        starred_at = stargazer["starred_at"]
        user["starred_at"] = starred_at
        trns_metric_json.append(user)
    
    metric_df = pd.DataFrame(trns_metric_json)
    metric_df["starred_at"] = pd.to_datetime(metric_df["starred_at"])
    metric_df = metric_df.set_index("starred_at")
    return metric_df

def extract_forks(metric_json):
    metric_df = pd.DataFrame(metric_json)
    metric_df["created_at"] = pd.to_datetime(metric_df["created_at"])
    metric_df = metric_df.set_index("created_at")
    return metric_df

extract_funcs = {"clones": extract_clones, 
                 "views": extract_views, 
                 "popular_paths": extract_popular_paths, 
                 "popular_referrers": extract_popular_referrers, 
                 "stargazers": extract_stargazers,
                 "forks": extract_forks}

# %% [markdown]
# ## Persistent Metrics

# %%
def cummulative_metric(metric_df, period="M"):
    return metric_df.resample(period).count().id.cumsum()

def list_blobs_within_folder(bucket_name, folder):
    """
    Gets blobs within a bucket folder.
    """
    storage_client = storage.Client()

    blobs = list(storage_client.list_blobs(bucket_name, prefix=folder))
    blobs = list(filter(lambda x: x.name != folder, blobs))
    return blobs

def get_recent_persistent_metric(metric):
    """
    Gets a dataframe of the most recent persistent metric data.
    """
    blobs = list_blobs_within_folder(BUCKET_NAME, metric + "/")
    most_recent_blob = sorted(blobs, key=lambda x: x.time_created)[-1]
    print(most_recent_blob)
    
    metric_json = json.loads(most_recent_blob.download_as_string())
    extract_func = extract_funcs[metric]
    most_recent_df = extract_func(metric_json)

    return most_recent_df

PERSISTENT_METRICS = ["stargazers", "forks"]

metric_dfs = {}
for metric in PERSISTENT_METRICS:
    metric_dfs[metric] = get_recent_persistent_metric(metric)
# Out:
# <Blob: github-metrics, stargazers/2021-10-26.json, 1635279552514881>
# <Blob: github-metrics, forks/2021-10-26.json, 1635279556304535>

# %%
forks = metric_dfs['forks']
stars = metric_dfs["stargazers"]

print(f"Current number of stars: {len(stars)}")
print(f"Current number of forks: {len(forks)}")
cummulative_metric(forks).plot()
cummulative_metric(stars).plot()
# Out:
# Current number of stars: 269
# Current number of forks: 65
# <AxesSubplot:xlabel='starred_at'>

# %% [markdown]
# ## Biweekly stats

# %%
def get_popular_metric(metric):
    blobs = list_blobs_within_folder(BUCKET_NAME, metric + "/")
    
    # get every other week. 
    blobs = sorted(blobs, key=lambda x: x.time_created)
    biweekly_blobs = blobs[::2]
    
    blob_dfs = []
    for blob in biweekly_blobs:
        metric_json = json.loads(blob.download_as_string())
        extract_func = extract_funcs[metric]
        blob_df = extract_func(metric_json)
        
        # Add timestamps to popular paths and referrers
        if "timestamp" not in blob_df.columns:
            blob_df["timestamp"] = blob.time_created
        
        blob_dfs.append(blob_df)
    
    metric_df = pd.concat(blob_dfs)
    return metric_df.set_index("timestamp")

def get_biweekly_metric(metric):
    blobs = list_blobs_within_folder(BUCKET_NAME, metric + "/")
    
    blob_dfs = []
    for blob in blobs:
        metric_json = json.loads(blob.download_as_string())
        extract_func = extract_funcs[metric]
        blob_df = extract_func(metric_json)
        
        # Remove first and last rows because of sliding window issue
        blob_df = blob_df.iloc[1:-1]
        
        blob_dfs.append(blob_df)
    
    # drop duplicates from overlapping weeks
    metric_df = pd.concat(blob_dfs).drop_duplicates()
    metric_df = metric_df.set_index("timestamp")
    assert metric_df.index.is_unique
    return metric_df
    

BIWEEKLY_METRICS = ["clones", "views"]
POPULAR_METRICS = ["popular_paths", "popular_referrers"]

for metric in BIWEEKLY_METRICS:
    print(metric)
    metric_dfs[metric] = get_biweekly_metric(metric)
    
# for metric in POPULAR_METRICS:
#     print(metric)
#     metric_dfs[metric] = get_popular_metric(metric)
# Out:
# clones
# views

# %%
metric_dfs['views'].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
metric_dfs["popular_paths"]
# Out:
#                                                                               path  \
# timestamp
# 2021-09-28 20:17:37.253000+00:00                 /catalyst-cooperative/pudl/issues
# 2021-09-28 20:17:37.253000+00:00               /catalyst-cooperative/pudl/tree/dev
# 2021-09-28 20:17:37.253000+00:00                  /catalyst-cooperative/pudl/pulls
# 2021-09-28 20:17:37.253000+00:00               /catalyst-cooperative/pudl/pull/806
# 2021-09-28 20:17:37.253000+00:00            /catalyst-cooperative/pudl/commits/dev
# 2021-09-28 20:17:37.253000+00:00   /catalyst-cooperative/pudl/tree/dedupe-metadata
# 2021-09-28 20:17:37.253000+00:00  /catalyst-cooperative/pudl/tree/redesign-harvest
# 2021-09-28 20:17:37.253000+00:00              /catalyst-cooperative/pudl/pull/1228
# 2021-10-05 20:18:11.494000+00:00                 /catalyst-cooperative/pudl/issues
# 2021-10-05 20:18:11.494000+00:00                /catalyst-cooperative/pudl/actions
# 2021-10-05 20:18:11.494000+00:00               /catalyst-cooperative/pudl/tree/dev
# 2021-10-05 20:18:11.494000+00:00                  /catalyst-cooperative/pudl/pulls
# 2021-10-05 20:18:11.494000+00:00            /catalyst-cooperative/pudl/commits/dev
# 2021-10-05 20:18:11.494000+00:00   /catalyst-cooperative/pudl/tree/dedupe-metadata
# 2021-10-05 20:18:11.494000+00:00               /catalyst-cooperative/pudl/pull/806
# 2021-10-05 20:18:11.494000+00:00     /catalyst-cooperative/pudl/tree/main/src/pudl
# 2021-10-12 20:18:44.160000+00:00                 /catalyst-cooperative/pudl/issues
# 2021-10-12 20:18:44.160000+00:00                /catalyst-cooperative/pudl/actions
# 2021-10-12 20:18:44.160000+00:00               /catalyst-cooperative/pudl/pull/806
# 2021-10-12 20:18:44.160000+00:00                  /catalyst-cooperative/pudl/pulls
# 2021-10-12 20:18:44.160000+00:00            /catalyst-cooperative/pudl/issues/1271
# 2021-10-12 20:18:44.160000+00:00     /catalyst-cooperative/pudl/tree/main/src/pudl
# 2021-10-12 20:18:44.160000+00:00               /catalyst-cooperative/pudl/tree/dev
# 2021-10-12 20:18:44.160000+00:00            /catalyst-cooperative/pudl/commits/dev
# 2021-10-19 20:18:43.522000+00:00                 /catalyst-cooperative/pudl/issues
# 2021-10-19 20:18:43.522000+00:00                /catalyst-cooperative/pudl/actions
# 2021-10-19 20:18:43.522000+00:00                  /catalyst-cooperative/pudl/pulls
# 2021-10-19 20:18:43.522000+00:00            /catalyst-cooperative/pudl/issues/1271
# 2021-10-19 20:18:43.522000+00:00     /catalyst-cooperative/pudl/tree/main/src/pudl
# 2021-10-19 20:18:43.522000+00:00             /catalyst-cooperative/pudl/issues/252
# 2021-10-19 20:18:43.522000+00:00    /catalyst-cooperative/pudl/tree/main/notebooks
# 2021-10-19 20:18:43.522000+00:00     /catalyst-cooperative/pudl/tree/main/devtools
# 2021-10-26 20:19:08.035000+00:00                 /catalyst-cooperative/pudl/issues
# 2021-10-26 20:19:08.035000+00:00                /catalyst-cooperative/pudl/actions
# 2021-10-26 20:19:08.035000+00:00                  /catalyst-cooperative/pudl/pulls
# 2021-10-26 20:19:08.035000+00:00             /catalyst-cooperative/pudl/issues/252
# 2021-10-26 20:19:08.035000+00:00    /catalyst-cooperative/pudl/tree/main/notebooks
# 2021-10-26 20:19:08.035000+00:00     /catalyst-cooperative/pudl/tree/main/src/pudl
# 2021-10-26 20:19:08.035000+00:00              /catalyst-cooperative/pudl/pull/1296
# 2021-10-26 20:19:08.035000+00:00     /catalyst-cooperative/pudl/tree/main/devtools
#
#                                                                               title  \
# timestamp
# 2021-09-28 20:17:37.253000+00:00        Issues · catalyst-cooperative/pudl · GitHub
# 2021-09-28 20:17:37.253000+00:00          GitHub - catalyst-cooperative/pudl at dev
# 2021-09-28 20:17:37.253000+00:00  Pull requests · catalyst-cooperative/pudl · Gi...
# 2021-09-28 20:17:37.253000+00:00  Redesign metadata and harvest process by ezwel...
# 2021-09-28 20:17:37.253000+00:00                Commits · catalyst-cooperative/pudl
# 2021-09-28 20:17:37.253000+00:00       catalyst-cooperative/pudl at dedupe-metadata
# 2021-09-28 20:17:37.253000+00:00      catalyst-cooperative/pudl at redesign-harvest
# 2021-09-28 20:17:37.253000+00:00  Dev PR for sprint ending 2021-09-24 by zanesel...
# 2021-10-05 20:18:11.494000+00:00        Issues · catalyst-cooperative/pudl · GitHub
# 2021-10-05 20:18:11.494000+00:00                Actions · catalyst-cooperative/pudl
# 2021-10-05 20:18:11.494000+00:00          GitHub - catalyst-cooperative/pudl at dev
# 2021-10-05 20:18:11.494000+00:00  Pull requests · catalyst-cooperative/pudl · Gi...
# 2021-10-05 20:18:11.494000+00:00                Commits · catalyst-cooperative/pudl
# 2021-10-05 20:18:11.494000+00:00       catalyst-cooperative/pudl at dedupe-metadata
# 2021-10-05 20:18:11.494000+00:00  Redesign metadata and harvest process by ezwel...
# 2021-10-05 20:18:11.494000+00:00  pudl/src/pudl at main · catalyst-cooperative/pudl
# 2021-10-12 20:18:44.160000+00:00        Issues · catalyst-cooperative/pudl · GitHub
# 2021-10-12 20:18:44.160000+00:00                Actions · catalyst-cooperative/pudl
# 2021-10-12 20:18:44.160000+00:00  Redesign metadata and harvest process by ezwel...
# 2021-10-12 20:18:44.160000+00:00  Pull requests · catalyst-cooperative/pudl · Gi...
# 2021-10-12 20:18:44.160000+00:00  Generalize process for standardizing and remap...
# 2021-10-12 20:18:44.160000+00:00  pudl/src/pudl at main · catalyst-cooperative/pudl
# 2021-10-12 20:18:44.160000+00:00                   catalyst-cooperative/pudl at dev
# 2021-10-12 20:18:44.160000+00:00                Commits · catalyst-cooperative/pudl
# 2021-10-19 20:18:43.522000+00:00        Issues · catalyst-cooperative/pudl · GitHub
# 2021-10-19 20:18:43.522000+00:00                Actions · catalyst-cooperative/pudl
# 2021-10-19 20:18:43.522000+00:00  Pull requests · catalyst-cooperative/pudl · Gi...
# 2021-10-19 20:18:43.522000+00:00  Generalize process for standardizing and remap...
# 2021-10-19 20:18:43.522000+00:00  pudl/src/pudl at main · catalyst-cooperative/p...
# 2021-10-19 20:18:43.522000+00:00  Use Pandas nullable Integer, Boolean, and Stri...
# 2021-10-19 20:18:43.522000+00:00  pudl/notebooks at main · catalyst-cooperative/...
# 2021-10-19 20:18:43.522000+00:00  pudl/devtools at main · catalyst-cooperative/p...
# 2021-10-26 20:19:08.035000+00:00        Issues · catalyst-cooperative/pudl · GitHub
# 2021-10-26 20:19:08.035000+00:00                Actions · catalyst-cooperative/pudl
# 2021-10-26 20:19:08.035000+00:00          Pull requests · catalyst-cooperative/pudl
# 2021-10-26 20:19:08.035000+00:00  Use Pandas nullable Integer, Boolean, and Stri...
# 2021-10-26 20:19:08.035000+00:00  pudl/notebooks at main · catalyst-cooperative/...
# 2021-10-26 20:19:08.035000+00:00  pudl/src/pudl at main · catalyst-cooperative/p...
# 2021-10-26 20:19:08.035000+00:00  Deduplicate natural key fields of generation_f...
# 2021-10-26 20:19:08.035000+00:00  pudl/devtools at main · catalyst-cooperative/p...
#
#                                   count  uniques
# timestamp
# 2021-09-28 20:17:37.253000+00:00     76        8
# 2021-09-28 20:17:37.253000+00:00     29        2
# 2021-09-28 20:17:37.253000+00:00     20        4
# 2021-09-28 20:17:37.253000+00:00     16        2
# 2021-09-28 20:17:37.253000+00:00     16        1
# 2021-09-28 20:17:37.253000+00:00     10        1
# 2021-09-28 20:17:37.253000+00:00     10        1
# 2021-09-28 20:17:37.253000+00:00      9        6
# 2021-10-05 20:18:11.494000+00:00     95       11
# 2021-10-05 20:18:11.494000+00:00     35        2
# 2021-10-05 20:18:11.494000+00:00     24        2
# 2021-10-05 20:18:11.494000+00:00     19        4
# 2021-10-05 20:18:11.494000+00:00     14        1
# 2021-10-05 20:18:11.494000+00:00     14        1
# 2021-10-05 20:18:11.494000+00:00     10        7
# 2021-10-05 20:18:11.494000+00:00      9        5
# 2021-10-12 20:18:44.160000+00:00     86        7
# 2021-10-12 20:18:44.160000+00:00     71        3
# 2021-10-12 20:18:44.160000+00:00     15        7
# 2021-10-12 20:18:44.160000+00:00     13        3
# 2021-10-12 20:18:44.160000+00:00     11        5
# 2021-10-12 20:18:44.160000+00:00      9        5
# 2021-10-12 20:18:44.160000+00:00      9        1
# 2021-10-12 20:18:44.160000+00:00      6        1
# 2021-10-19 20:18:43.522000+00:00     65        8
# 2021-10-19 20:18:43.522000+00:00     53        1
# 2021-10-19 20:18:43.522000+00:00     38        3
# 2021-10-19 20:18:43.522000+00:00      9        7
# 2021-10-19 20:18:43.522000+00:00      6        3
# 2021-10-19 20:18:43.522000+00:00      5        4
# 2021-10-19 20:18:43.522000+00:00      5        3
# 2021-10-19 20:18:43.522000+00:00      5        1
# 2021-10-26 20:19:08.035000+00:00     57        8
# 2021-10-26 20:19:08.035000+00:00     44        1
# 2021-10-26 20:19:08.035000+00:00     33        3
# 2021-10-26 20:19:08.035000+00:00      5        4
# 2021-10-26 20:19:08.035000+00:00      5        3
# 2021-10-26 20:19:08.035000+00:00      5        3
# 2021-10-26 20:19:08.035000+00:00      5        1
# 2021-10-26 20:19:08.035000+00:00      5        1

# %%
metric_dfs["popular_referrers"]
# Out:
#                                                           referrer  count  \
# timestamp
# 2021-09-28 20:17:37.546000+00:00                        github.com     94
# 2021-09-28 20:17:37.546000+00:00                            Google     43
# 2021-09-28 20:17:37.546000+00:00          url.emailprotection.link     15
# 2021-09-28 20:17:37.546000+00:00                     catalyst.coop      8
# 2021-09-28 20:17:37.546000+00:00            towardsdatascience.com      8
# 2021-09-28 20:17:37.546000+00:00             com.google.android.gm      7
# 2021-09-28 20:17:37.546000+00:00  catalystcoop-pudl.readthedocs.io      4
# 2021-09-28 20:17:37.546000+00:00                        zenodo.org      4
# 2021-09-28 20:17:37.546000+00:00                data.catalyst.coop      2
# 2021-09-28 20:17:37.546000+00:00              github.innominds.com      1
#
#                                   uniques
# timestamp
# 2021-09-28 20:17:37.546000+00:00       37
# 2021-09-28 20:17:37.546000+00:00       13
# 2021-09-28 20:17:37.546000+00:00        1
# 2021-09-28 20:17:37.546000+00:00        8
# 2021-09-28 20:17:37.546000+00:00        3
# 2021-09-28 20:17:37.546000+00:00        3
# 2021-09-28 20:17:37.546000+00:00        4
# 2021-09-28 20:17:37.546000+00:00        1
# 2021-09-28 20:17:37.546000+00:00        2
# 2021-09-28 20:17:37.546000+00:00        1
